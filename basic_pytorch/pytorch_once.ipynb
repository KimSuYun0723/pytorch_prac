# %% [markdown]
# # 파이토치(Pytorch)
# - 페이스북이 초기 루아(Lua) 언어로 개발된 토치(Torch)를 파이썬 버전으로 개발하여 2017년도에 공개
# - 즉 토치 인데 파이썬이어서 파이토치.
# - 초기에 토치는 넘파이 라이브러리처럼 과학 연산을 위한 라이브러리로 공개
# - GPU를 이용한 텐서 조작 및 동적 신경망 구축이 가능하도록 딥러닝 프레임워크로 발전
# - 파이썬 답게 만들어졌고 유연하면서도 가속화된 계산 속도

# %% [markdown]
# [Pytorch Architecture](https://www.google.com/url?sa=i&url=https%3A%2F%2Fresultofeffort.tistory.com%2F77&psig=AOvVaw3tZSNLAlRSKcYVofUQk56p&ust=1725449636935000&source=images&cd=vfe&opi=89978449&ved=0CBQQjRxqFwoTCIidi_fWpogDFQAAAAAdAAAAABAR)
# ![image.png](attachment:image-2.png)

# %% [markdown]
# ## 파이토치의 구성요소
# - torch : 메인 네임스페이스, 텐서 등 다양한 수학 함수 포함
# - torch.autograd : 자동미분 기능
# - torch.nn : 신경망 구축을 위한 데이터 구조나 레이어 등의 라이브러리
# - torch.multiprocessing : 병렬처리 기능을 제공하는 라이브러리
# - torch.optim : SGD(Stochastic Gradient Descent)를 중심으로 한 파라미터 최적화 알고리즘 제공
# - torch.utils : 데이터 주작 등 유틸리티 기능 제공
# - torch.onnx : ONNX(Open Neural Network Exchange) : 다른 프레임워크 간 모델을 공유 시 사용

# %% [markdown]
# ### 텐서(Tensors)
# - 데이터 표현을 위한 기본 구조
# - 데이터를 담기 위한 컨테이너로서 일반적으로 수치형 데이터 담음
# - 넘파이로 따지면 ndarray와 유사
# - GPU를 사용한 연산 가속 가능
#
# ![image.png](attachment:image.png)

# %%
import torch

torch.__version__
# Out:
# '2.3.0+cpu'

# %% [markdown]
# #### 텐서 초기화와 데이터타입

# %% [markdown]
# 초기화 되지 않은 텐서
# - GPU(CUDA) 사용 시: 초기화되지 않은 메모리의 임의의 값
# - CPU 사용 시: 초기화되지 않은 메모리가 0으로 설정, 좀더 안정적일 수 있음
# : 나의 노트북은 cpu 쓰고 있기 때문에 0으로 나옴

# %%
x = torch.empty(4,2)
print(x)
# Out:
# tensor([[0., 0.],
#         [0., 0.],
#         [0., 0.],
#         [0., 0.]])

# %% [markdown]
# 무작위로 초기화된 텐서

# %%
x = torch.rand(4,2)
print(x)
# Out:
# tensor([[0.4856, 0.7613],
#         [0.9084, 0.9036],
#         [0.2418, 0.0831],
#         [0.7809, 0.4803]])

# %% [markdown]
# 데이터 타입이 long이고 0으로 채워진 텐서

# %%
x = torch.zeros(4,2, dtype=torch.long)
print(x)
# Out:
# tensor([[0, 0],
#         [0, 0],
#         [0, 0],
#         [0, 0]])

# %% [markdown]
# 사용자가 입력한 값으로 텐서 초기화

# %%
x = torch.tensor([3,2.3])
print(x)
# Out:
# tensor([3.0000, 2.3000])

# %% [markdown]
# 2*4 크기, double type, 1로 채워진 텐서

# %%
x = x.new_ones(2,4, dtype=torch.double)
print(x)
# Out:
# tensor([[1., 1., 1., 1.],
#         [1., 1., 1., 1.]], dtype=torch.float64)

# %% [markdown]
# x와 같은 크기, float 타입, 무작위로 채워진 텐서

# %%
x = torch.randn_like(x, dtype = torch.float)
print(x)
# Out:
# tensor([[-0.3112, -0.1377,  0.4306, -0.5731],
#         [-0.5756, -0.7009, -0.3821,  0.8867]])

# %% [markdown]
# 텐서의 크기 계산

# %%
print(x.size())
# Out:
# torch.Size([2, 4])

# %% [markdown]
# #### 데이터 타입
