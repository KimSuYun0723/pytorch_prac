# %% [markdown]
# # RNN 직접 구현해보기

# %% [markdown]
# - 참고 사이트
# : https://tutorials.pytorch.kr/intermediate/char_rnn_classification_tutorial.html
# - Colab 참고
# : https://colab.research.google.com/github/pytorch/tutorials/blob/gh-pages/_downloads/char_rnn_classification_tutorial.ipynb#scrollTo=C3hSQS6w-oKf

# %% [markdown]
# ## 0. Data Convention
# 1. Defining objects
# - line = 이름
# - category = 언어(클래스)
#
# 2. Name
# 1) 로마자 유니코드 --> ASCII
# 2) 이름 --> Tensor

# %%
from __future__ import unicode_literals, print_function, division
from io import open
import glob
import os

# %%
# glob 함수: 파일명을 리스트 형식으로 반환
def findFiles(path): return glob.glob(path) 
print(findFiles('data/names/*.txt'))

import unicodedata
import string

all_letters = string.ascii_latters + ".,;'"
n_letters = len(all_letters)

def unicodeToAscii(s):
    return ''.join(
        c for c in unicodedata.normalize('NFD', s)
        if unicodedata.category(c) != 'Mn'
        and c in all_letters
    )

print(unicodeToAscii('Ślusàrski'))


category_lines = {}
all_categories = []

def readLines(filename):
    lines = open(filename, encoding='utf-8').read().strip().split('\n')
    return [unicodeToAscii(line) for line in lines]

for filename in findFiles('data/names/*.txt'):
    category = os.path.splittext(os.path.basename(filename))[0]
    all_categories.append(category)
    lines = readLines(filename)
    category_lines[category] = lines

n_categories = len(all_categories)

# %%
def letterToIndex(letter):
    return all_letters.find(letter)

def letterToTensor(letter):
    tensor = torch.zeros(1,n_letters)
    tensor[0][letterToIndex(letter)] = 1
    return tensor
