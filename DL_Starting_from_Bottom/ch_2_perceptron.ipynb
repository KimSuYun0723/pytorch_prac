# %% [markdown]
# # 2.2. Simple Logical Gates

# %% [markdown]
# ### 2.2.1. AND gate

# %% [markdown]
# ##### AND gate truth table
# |x1|x2|y|
# |------|---|---|
# |0|0|0|
# |1|0|0|
# |0|1|0|
# |1|1|1|

# %% [markdown]
# ### 2.2.2. NAND gate & OR gate

# %% [markdown]
# ##### NAND gate truth table
# |x1|x2|y|
# |------|---|---|
# |0|0|1|
# |1|0|1|
# |0|1|1|
# |1|1|0|

# %% [markdown]
# ##### OR gate truth table
# |x1|x2|y|
# |------|---|---|
# |0|0|0|
# |1|0|1|
# |0|1|1|
# |1|1|1|

# %% [markdown]
# # 2.3. Making Perceptron

# %% [markdown]
# ### Simple challenge
